# %%
print ("hello")
# Out:
# hello

# %%
a = 1
b = 2
if a<b: 
    print ("a is less than b")
    print ("a is definitely less than b")
print ("Not sure")
# Out:
# a is less than b
# a is definitely less than b
# Not sure

# %%
c = 5
d = 4

if c < d: 
    print ("c is less than d")
else:
    print ("c is not less than d")
    print ("i dont think so")
print ("outside the if statement")
# Out:
# c is not less than d
# i dont think so
# outside the if statement

# %%
''' Demo of Python-Postgres Connection: '''

import matplotlib.pyplot as plt
import psycopg2

conn = psycopg2.connect(database='classwork', user='postgres')
cur = conn.cursor()

sql = """select horsepower, mpg
            from cars
            where mpg <> 0
            and horsepower <> 0
            order by horsepower;"""

cur.execute(sql)
result = cur.fetchall()

cur.close()
conn.close()

# for item in result:
#    print(item)

x = [item[0] for item in result]
y = [item[1] for item in result]

colors = [2 * item for item in y]  # just use our numeric data

plt.scatter(x, y, c=colors)
plt.title("MPG vs Horsepower")
plt.ylabel("Miles Per Gallon")
plt.xlabel("Horsepower")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-626168eb943b> in <module>()
#       1 ''' Demo of Python-Postgres Connection: '''
#       2
# ----> 3 import matplotlib.pyplot as plt
#       4 import psycopg2
#       5
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-64b6e804fec3> in <module>()
# ----> 1 import matplotlib.pyplot as plt
#       2 plt.plot([1,2,3,4])
#       3 plt.ylabel('some numbers')
#       4 plt.show()
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
import matplotlib.pyplot as plt
import psycopg2

conn = psycopg2.connect(database='classwork', user='postgres')
cur = conn.cursor()

sql = """select horsepower, mpg
            from cars
            where mpg <> 0
            and horsepower <> 0
            order by horsepower;"""

cur.execute(sql)
result = cur.fetchall()

cur.close()
conn.close()

# for item in result:
#    print(item)

x = [item[0] for item in result]
y = [item[1] for item in result]

colors = [2 * item for item in y]  # just use our numeric data

plt.scatter(x, y, c=colors)
plt.title("MPG vs Horsepower")
plt.ylabel("Miles Per Gallon")
plt.xlabel("Horsepower")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-9056f627b109> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 import psycopg2
#       3
#       4 conn = psycopg2.connect(database='classwork', user='postgres')
#       5 cur = conn.cursor()
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
import matplotlib.pyplot as plt
import psycopg2

conn = psycopg2.connect(database='classwork', user='postgres')
cur = conn.cursor()

sql = """select horsepower, mpg
            from cars
            where mpg <> 0
            and horsepower <> 0
            order by horsepower;"""

cur.execute(sql)
result = cur.fetchall()

cur.close()
conn.close()

# for item in result:
#    print(item)

x = [item[0] for item in result]
y = [item[1] for item in result]

colors = [2 * item for item in y]  # just use our numeric data

plt.scatter(x, y, c=colors)
plt.title("MPG vs Horsepower")
plt.ylabel("Miles Per Gallon")
plt.xlabel("Horsepower")
plt.show()

# %%
import matplotlib.pyplot as plt
import psycopg2

conn = psycopg2.connect(database='Assn2', user='postgres')
cur = conn.cursor()

sql = """select *
            from city
            ;"""

cur.execute(sql)
result = cur.fetchall()

cur.close()
conn.close()

# for item in result:
#    print(item)

x = [item[0] for item in result]
y = [item[1] for item in result]

colors = [2 * item for item in y]  # just use our numeric data

plt.scatter(x, y, c=colors)
plt.title("MPG vs Horsepower")
plt.ylabel("Miles Per Gallon")
plt.xlabel("Horsepower")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Public\Documents\AnacondaPython\envs\rstudio\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     165     try:
# --> 166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: ('KabulKabul', None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\Public\Documents\AnacondaPython\envs\rstudio\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4273                 # must be acceptable as PathCollection facecolors
# -> 4274                 colors = mcolors.to_rgba_array(c)
#    4275             except ValueError:
#
# C:\Users\Public\Documents\AnacondaPython\envs\rstudio\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     266     for i, cc in enumerate(c):
# --> 267         result[i] = to_rgba(cc, alpha)
#     268     return result
#
# C:\Users\Public\Documents\AnacondaPython\envs\rstudio\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 168         rgba = _to_rgba_no_colorcycle(c, alpha)
#     169         try:
#
# C:\Users\Public\Documents\AnacondaPython\envs\rstudio\lib\site-packages\matplotlib\colors.py in _to_rgba_no_colorcycle(c, alpha)
#     211             pass
# --> 212         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     213     # tuple color.
#
# ValueError: Invalid RGBA argument: 'KabulKabul'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-8e1fbe357a6f> in <module>()
#      23 colors = [2 * item for item in y]  # just use our numeric data
#      24
# ---> 25 plt.scatter(x, y, c=colors)
#      26 plt.title("MPG vs Horsepower")
#      27 plt.ylabel("Miles Per Gallon")
#
# C:\Users\Public\Documents\AnacondaPython\envs\rstudio\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3468                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3469                          linewidths=linewidths, verts=verts,
# -> 3470                          edgecolors=edgecolors, data=data, **kwargs)
#    3471     finally:
#    3472         ax._hold = washold
#
# C:\Users\Public\Documents\AnacondaPython\envs\rstudio\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\Users\Public\Documents\AnacondaPython\envs\rstudio\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4277                 raise ValueError("c of shape {} not acceptable as a color "
#    4278                                  "sequence for x with size {}, y with size {}"
# -> 4279                                  .format(c.shape, x.size, y.size))
#    4280         else:
#    4281             colors = None  # use cmap, norm after collection is created
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
import matplotlib.pyplot as plt
import psycopg2

conn = psycopg2.connect(database='classwork', user='postgres')
cur = conn.cursor()

sql = """select horsepower, mpg
            from cars
            where mpg <> 0
            and horsepower <> 0
            order by horsepower;"""

cur.execute(sql)
result = cur.fetchall()

cur.close()
conn.close()

# for item in result:
#    print(item)

x = [item[0] for item in result]
y = [item[1] for item in result]

colors = [2 * item for item in y]  # just use our numeric data

plt.scatter(x, y, c=colors)
plt.title("MPG vs Horsepower")
plt.ylabel("Miles Per Gallon")
plt.xlabel("Horsepower")
plt.show()

# %%
import matplotlib.pyplot as plt
import psycopg2

conn = psycopg2.connect(database='classwork', user='postgres')
cur = conn.cursor()

sql = """select horsepower, mpg
            from cars
            where mpg <> 0
            and horsepower <> 0
            order by horsepower;"""

cur.execute(sql)
result = cur.fetchall()

cur.close()
conn.close()

# for item in result:
#    print(item)

x = [item[0] for item in result]
y = [item[1] for item in result]

colors = [2 * item for item in y]  # just use our numeric data

plt.scatter(x, y, c=colors)
plt.title("MPG vs Horsepower")
plt.ylabel("Miles Per Gallon")
plt.xlabel("Horsepower")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9056f627b109> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 import psycopg2
#       3
#       4 conn = psycopg2.connect(database='classwork', user='postgres')
#       5 cur = conn.cursor()
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
import matplotlib.pyplot as plt
import psycopg2

conn = psycopg2.connect(database='classwork', user='postgres')
cur = conn.cursor()

sql = """select horsepower, mpg
            from cars
            where mpg <> 0
            and horsepower <> 0
            order by horsepower;"""

cur.execute(sql)
result = cur.fetchall()

cur.close()
conn.close()

# for item in result:
#    print(item)

x = [item[0] for item in result]
y = [item[1] for item in result]

colors = [2 * item for item in y]  # just use our numeric data

plt.scatter(x, y, c=colors)
plt.title("MPG vs Horsepower")
plt.ylabel("Miles Per Gallon")
plt.xlabel("Horsepower")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([2,5,3,1])
plt.ylabel('some numbers')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,10])
plt.ylabel('some numbers')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([10,2,2,3])
plt.ylabel('some numbers')
plt.show()

# %%
import matplotlib.pyplot as plt
import psycopg2

conn = psycopg2.connect(database='classwork', user='postgres')
cur = conn.cursor()

sql = """select horsepower, mpg
            from cars
            where mpg <> 0
            and horsepower <> 0
            order by horsepower;"""

cur.execute(sql)
result = cur.fetchall()

cur.close()
conn.close()

# for item in result:
#    print(item)

x = [item[0] for item in result]
y = [item[1] for item in result]

colors = [2 * item for item in y]  # just use our numeric data

plt.plot(x, y, c=colors)
plt.title("MPG vs Horsepower")
plt.ylabel("Miles Per Gallon")
plt.xlabel("Horsepower")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     165     try:
# --> 166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2210                     orientation=orientation,
#    2211                     dryrun=True,
# -> 2212                     **kwargs)
#    2213                 renderer = self.figure._cachedRenderer
#    2214                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     511
#     512     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 513         FigureCanvasAgg.draw(self)
#     514         renderer = self.get_renderer()
#     515         original_dpi = renderer.dpi
#
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     431             # if toolbar:
#     432             #     toolbar.set_cursor(cursors.WAIT)
# --> 433             self.figure.draw(self.renderer)
#     434             # A GUI class may be need to update a window using this draw, so
#     435             # don't forget to call the superclass.
#
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1473
#    1474             mimage._draw_list_compositing_images(
# -> 1475                 renderer, self, artists, self.suppressComposite)
#    1476
#    1477             renderer.close_group('figure')
#
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2605             renderer.stop_rasterizing()
#    2606
# -> 2607         mimage._draw_list_compositing_images(renderer, self, artists)
#    2608
#    2609         renderer.close_group('axes')
#
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\matplotlib\lines.py in draw(self, renderer)
#     759                 self._set_gc_clip(gc)
#     760
# --> 761                 ln_color_rgba = self._get_rgba_ln_color()
#     762                 gc.set_foreground(ln_color_rgba, isRGBA=True)
#     763                 gc.set_alpha(ln_color_rgba[3])
#
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\matplotlib\lines.py in _get_rgba_ln_color(self, alt)
#    1260
#    1261     def _get_rgba_ln_color(self, alt=False):
# -> 1262         return mcolors.to_rgba(self._color, self._alpha)
#    1263
#    1264     # some aliases....
#
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 168         rgba = _to_rgba_no_colorcycle(c, alpha)
#     169         try:
#     170             _colors_full_map.cache[c, alpha] = rgba
#
# C:\Users\Public\Documents\AnacondaPython\lib\site-packages\matplotlib\colors.py in _to_rgba_no_colorcycle(c, alpha)
#     221     c = tuple(c.astype(float))
#     222     if len(c) not in [3, 4]:
# --> 223         raise ValueError("RGBA sequence should have length 3 or 4")
#     224     if len(c) == 3 and alpha is None:
#     225         alpha = 1
#
# ValueError: RGBA sequence should have length 3 or 4

# %%
import numpy as np
import matplotlib.pyplot as plt

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
import matplotlib.pyplot as plt
import psycopg2

conn = psycopg2.connect(database='classwork', user='postgres')
cur = conn.cursor()

sql = """select horsepower, mpg
            from cars
            where mpg <> 0
            and horsepower <> 0
            order by horsepower;"""

cur.execute(sql)
result = cur.fetchall()

cur.close()
conn.close()

# for item in result:
#    print(item)

x = [item[0] for item in result]
y = [item[1] for item in result]

colors = [2 * item for item in r]  # just use our numeric data

plt.scatter(x, y, c=colors)
plt.title("MPG vs Horsepower")
plt.ylabel("Miles Per Gallon")
plt.xlabel("Horsepower")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-71f099578d21> in <module>()
#      23 y = [item[1] for item in result]
#      24
# ---> 25 colors = [2 * item for item in r]  # just use our numeric data
#      26
#      27 plt.scatter(x, y, c=colors)
#
# NameError: name 'r' is not defined

# %%
import matplotlib.pyplot as plt
import psycopg2

conn = psycopg2.connect(database='classwork', user='postgres')
cur = conn.cursor()

sql = """select horsepower, mpg
            from cars
            where mpg <> 0
            and horsepower <> 0
            order by horsepower;"""

cur.execute(sql)
result = cur.fetchall()

cur.close()
conn.close()

# for item in result:
#    print(item)

x = [item[0] for item in result]
y = [item[1] for item in result]

colors = [2 * item for item in x]  # just use our numeric data

plt.scatter(x, y, c=colors)
plt.title("MPG vs Horsepower")
plt.ylabel("Miles Per Gallon")
plt.xlabel("Horsepower")
plt.show()

# %%
import matplotlib.pyplot as plt
import psycopg2

conn = psycopg2.connect(database='classwork', user='postgres')
cur = conn.cursor()

sql = """select horsepower, mpg
            from cars
            where mpg <> 0
            and horsepower <> 0
            order by horsepower;"""

cur.execute(sql)
result = cur.fetchall()

cur.close()
conn.close()

# for item in result:
#    print(item)

x = [item[0] for item in result]
y = [item[1] for item in result]

colors = [2 * item for item in y]  # just use our numeric data

plt.scatter(x, y, c=colors)
plt.title("MPG vs Horsepower")
plt.ylabel("Miles Per Gallon")
plt.xlabel("Horsepower")
plt.show()

# %%
import matplotlib.pyplot as plt
import psycopg2

conn = psycopg2.connect(database='classwork', user='postgres')
cur = conn.cursor()

sql = """select horsepower, mpg
            from cars
            where mpg <> 0
            and horsepower <> 0
            order by horsepower;"""

cur.execute(sql)
result = cur.fetchall()

cur.close()
conn.close()

# for item in result:
#    print(item)

x = [item[0] for item in result]
y = [item[1] for item in result]

colors = [4 * item for item in y]  # just use our numeric data

plt.scatter(x, y, c=colors)
plt.title("MPG vs Horsepower")
plt.ylabel("Miles Per Gallon")
plt.xlabel("Horsepower")
plt.show()

# %%
import matplotlib.pyplot as plt
import psycopg2

conn = psycopg2.connect(database='classwork', user='postgres')
cur = conn.cursor()

sql = """select horsepower, mpg
            from cars
            where mpg <> 0
            and horsepower <> 0
            order by horsepower;"""

cur.execute(sql)
result = cur.fetchall()

cur.close()
conn.close()

# for item in result:
#    print(item)

x = [item[0] for item in result]
y = [item[1] for item in result]

colors = [1 * item for item in y]  # just use our numeric data

plt.scatter(x, y, c=colors)
plt.title("MPG vs Horsepower")
plt.ylabel("Miles Per Gallon")
plt.xlabel("Horsepower")
plt.show()

# %%
import matplotlib.pyplot as plt
import psycopg2

conn = psycopg2.connect(database='classwork', user='postgres')
cur = conn.cursor()

sql = """select horsepower, mpg
            from cars
            where mpg <> 0
            and horsepower <> 0
            order by horsepower;"""

cur.execute(sql)
result = cur.fetchall()

cur.close()
conn.close()

# for item in result:
#    print(item)

x = [item[0] for item in result]
y = [item[1] for item in result]

colors = [100 * item for item in y]  # just use our numeric data

plt.scatter(x, y, c=colors)
plt.title("MPG vs Horsepower")
plt.ylabel("Miles Per Gallon")
plt.xlabel("Horsepower")
plt.show()

# %%
import matplotlib.pyplot as plt
import psycopg2

conn = psycopg2.connect(database='classwork', user='postgres')
cur = conn.cursor()

sql = """select horsepower, mpg
            from cars
            where mpg <> 0
            and horsepower <> 0
            order by horsepower;"""

cur.execute(sql)
result = cur.fetchall()

cur.close()
conn.close()

# for item in result:
#    print(item)

x = [item[0] for item in result]
y = [item[1] for item in result]

colors = [ item for item in y]  # just use our numeric data

plt.scatter(x, y, c=colors)
plt.title("MPG vs Horsepower")
plt.ylabel("Miles Per Gallon")
plt.xlabel("Horsepower")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=r, alpha=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-94eedc2b0ad3> in <module>()
#      12 area = (30 * np.random.rand(N))**2  # 0 to 15 point radii
#      13
# ---> 14 plt.scatter(x, y, s=area, c=r, alpha=0.5)
#      15 plt.show()
#
# NameError: name 'r' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = r
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-569713a213be> in <module>()
#       9 x = np.random.rand(N)
#      10 y = np.random.rand(N)
# ---> 11 colors = r
#      12 area = (30 * np.random.rand(N))**2  # 0 to 15 point radii
#      13
#
# NameError: name 'r' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt


# Fixing random state for reproducibility
np.random.seed(19680801)

# Compute areas and colors
N = 150
r = 2 * np.random.rand(N)
theta = 2 * np.pi * np.random.rand(N)
area = 200 * r**2
colors = theta

fig = plt.figure()
ax = fig.add_subplot(111, projection='polar')
c = ax.scatter(theta, r, c=colors, s=area, cmap='hsv', alpha=0.75)

# %%
import numpy as np
import matplotlib.pyplot as plt


# Fixing random state for reproducibility
np.random.seed(0)

# Compute areas and colors
N = 150
r = 2 * np.random.rand(N)
theta = 2 * np.pi * np.random.rand(N)
area = 200 * r**2
colors = theta

fig = plt.figure()
ax = fig.add_subplot(111, projection='polar')
c = ax.scatter(theta, r, c=colors, s=area, cmap='hsv', alpha=0.75)
